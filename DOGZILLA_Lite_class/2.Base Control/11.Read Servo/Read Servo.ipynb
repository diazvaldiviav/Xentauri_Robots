# %%
from xgolib import XGO
import time
import ipywidgets as widgets
from IPython.display import display
from ipywidgets import interact, widgets, Button, VBox, IntSlider

dog = XGO("xgolite")

# %%
while True:
    print(dog.read_motor())
    time.sleep(1)
# Out:
# [4.35, 36.67, 0.82, 3.88, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.59, 4.35, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.59, 3.88, 37.92, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.92, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.59, 3.88, 37.29, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.92, 0.59, 3.41, 47.96, -0.35, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.92, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 4.35, 37.92, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.92, 0.59, 3.88, 47.96, -0.35, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.59, 4.35, 37.29, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.59, 4.35, 37.92, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.59, 4.35, 37.29, 0.59, 3.88, 47.96, -0.12, 3.88, 47.33, 1.76, -0.25, 70.0, -85.0]
# [4.82, 36.67, 0.59, 3.88, 37.29, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.76, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 3.88, 37.29, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.76, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.82, 4.35, 37.29, 0.82, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.76, 70.0, -85.0]
# [4.35, 36.67, 0.59, 3.88, 37.92, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.59, 3.88, 37.29, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# [4.35, 36.67, 0.59, 3.88, 37.92, 0.59, 3.88, 47.96, -0.12, 4.35, 47.33, 1.53, -0.25, 70.0, -85.0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 while True:
#       2     print(dog.read_motor())
# ----> 3     time.sleep(1)
#
# KeyboardInterrupt:
